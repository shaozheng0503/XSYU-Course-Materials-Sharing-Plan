# %%
import pandas as pd  
  
# 读取Excel文件  
df = pd.read_excel('C:\\Users\\Sun\\Desktop\\石工大赛\\方法二\\整理后总数据 - 相关性分析.xlsx', engine='openpyxl')  
  
# 计算相关性矩阵  
correlation_matrix = df.corr()  
  
# 打印相关性矩阵  
print(correlation_matrix)
# Out:
#               井径      补偿中子      声波时差      自然伽马    深侧向电阻率    浅侧向电阻率    岩性密度矫正
# 井径      1.000000  0.182655  0.057748 -0.092188 -0.048959 -0.040651 -0.401320
# 补偿中子    0.182655  1.000000  0.042123 -0.025624 -0.006062 -0.005314 -0.051546
# 声波时差    0.057748  0.042123  1.000000  0.007876 -0.192870 -0.139310 -0.330325
# 自然伽马   -0.092188 -0.025624  0.007876  1.000000 -0.068873 -0.040374  0.171779
# 深侧向电阻率 -0.048959 -0.006062 -0.192870 -0.068873  1.000000  0.607629  0.100924
# 浅侧向电阻率 -0.040651 -0.005314 -0.139310 -0.040374  0.607629  1.000000  0.101393
# 岩性密度矫正 -0.401320 -0.051546 -0.330325  0.171779  0.100924  0.101393  1.000000

# %%
import seaborn as sns  
import matplotlib.pyplot as plt
# 生成热图  
plt.figure(figsize=(10, 8))  
sns.heatmap(correlation_matrix,   
            xticklabels=correlation_matrix.columns.values,  
            yticklabels=correlation_matrix.columns.values,  
            annot=True,  
            cmap='RdYlGn')  
plt.show()
# Out:
# C:\Users\Sun\anaconda3\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 20117 (\N{CJK UNIFIED IDEOGRAPH-4E95}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# C:\Users\Sun\anaconda3\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 24452 (\N{CJK UNIFIED IDEOGRAPH-5F84}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# C:\Users\Sun\anaconda3\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 34917 (\N{CJK UNIFIED IDEOGRAPH-8865}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# C:\Users\Sun\anaconda3\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 20607 (\N{CJK UNIFIED IDEOGRAPH-507F}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# C:\Users\Sun\anaconda3\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 20013 (\N{CJK UNIFIED IDEOGRAPH-4E2D}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# ...
